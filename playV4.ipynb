# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import seaborn as sns
import statsmodels.api as sm
import warnings
import math

# %%
df = pd.read_csv("WDIData.csv").iloc[:, :-1]

# country_df only contains countries, excludes Arab World, Continents and so on...
country_df = df.iloc[67400:]

# %%
grps = df.groupby(["Country Code", "Indicator Code"])

# %%
grps.groups
# Out:
# {('ABW', 'AG.AGR.TRAC.NO'): [80364], ('ABW', 'AG.CON.FERT.PT.ZS'): [80724], ('ABW', 'AG.CON.FERT.ZS'): [80725], ('ABW', 'AG.LND.AGRI.K2'): [80363], ('ABW', 'AG.LND.AGRI.ZS'): [80362], ('ABW', 'AG.LND.ARBL.HA'): [80395], ('ABW', 'AG.LND.ARBL.HA.PC'): [80394], ('ABW', 'AG.LND.ARBL.ZS'): [80393], ('ABW', 'AG.LND.CREL.HA'): [80993], ('ABW', 'AG.LND.CROP.ZS'): [81278], ('ABW', 'AG.LND.EL5M.RU.K2'): [81491], ('ABW', 'AG.LND.EL5M.RU.ZS'): [81490], ('ABW', 'AG.LND.EL5M.UR.K2'): [81707], ('ABW', 'AG.LND.EL5M.UR.ZS'): [81706], ('ABW', 'AG.LND.EL5M.ZS'): [80992], ('ABW', 'AG.LND.FRST.K2'): [80762], ('ABW', 'AG.LND.FRST.ZS'): [80761], ('ABW', 'AG.LND.IRIG.AG.ZS'): [80361], ('ABW', 'AG.LND.PRCP.MM'): [80403], ('ABW', 'AG.LND.TOTL.K2'): [80991], ('ABW', 'AG.LND.TOTL.RU.K2'): [81489], ('ABW', 'AG.LND.TOTL.UR.K2'): [81705], ('ABW', 'AG.LND.TRAC.ZS'): [80365], ('ABW', 'AG.PRD.CREL.MT'): [80443], ('ABW', 'AG.PRD.CROP.XD'): [80585], ('ABW', 'AG.PRD.FOOD.XD'): [80754], ('ABW', 'AG.PRD.LVSK.XD'): [81012], ('ABW', 'AG.SRF.TOTL.K2'): [81579], ('ABW', 'AG.YLD.CREL.KG'): [80444], ('ABW', 'BG.GSR.NFSV.GD.ZS'): [81651], ('ABW', 'BM.GSR.CMCP.ZS'): [80516], ('ABW', 'BM.GSR.FCTY.CD'): [81427], ('ABW', 'BM.GSR.GNFS.CD'): [80898], ('ABW', 'BM.GSR.INSF.ZS'): [80937], ('ABW', 'BM.GSR.MRCH.CD'): [80814], ('ABW', 'BM.GSR.NFSV.CD'): [81540], ('ABW', 'BM.GSR.ROYL.CD'): [80448], ('ABW', 'BM.GSR.TOTL.CD'): [80903], ('ABW', 'BM.GSR.TRAN.ZS'): [81675], ('ABW', 'BM.GSR.TRVL.ZS'): [81679], ('ABW', 'BM.KLT.DINV.CD.WD'): [80760], ('ABW', 'BM.KLT.DINV.WD.GD.ZS'): [80759], ('ABW', 'BM.TRF.PRVT.CD'): [81533], ('ABW', 'BM.TRF.PWKR.CD.DT'): [81285], ('ABW', 'BN.CAB.XOKA.CD'): [80587], ('ABW', 'BN.CAB.XOKA.GD.ZS'): [80586], ('ABW', 'BN.FIN.TOTL.CD'): [81150], ('ABW', 'BN.GSR.FCTY.CD'): [81205], ('ABW', 'BN.GSR.GNFS.CD'): [81214], ('ABW', 'BN.GSR.MRCH.CD'): [81213], ('ABW', 'BN.KAC.EOMS.CD'): [81149], ('ABW', 'BN.KLT.DINV.CD'): [80756], ('ABW', 'BN.KLT.PTXL.CD'): [81366], ('ABW', 'BN.RES.INCL.CD'): [81483], ('ABW', 'BN.TRF.CURR.CD'): [81209], ('ABW', 'BN.TRF.KOGT.CD'): [81147], ('ABW', 'BX.GRT.EXTA.CD.WD'): [80822], ('ABW', 'BX.GRT.TECH.CD.WD'): [81612], ('ABW', 'BX.GSR.CCIS.CD'): [80886], ('ABW', 'BX.GSR.CCIS.ZS'): [80885], ('ABW', 'BX.GSR.CMCP.ZS'): [80515], ('ABW', 'BX.GSR.FCTY.CD'): [81428], ('ABW', 'BX.GSR.GNFS.CD'): [80701], ('ABW', 'BX.GSR.INSF.ZS'): [80936], ('ABW', 'BX.GSR.MRCH.CD'): [80813], ('ABW', 'BX.GSR.NFSV.CD'): [81539], ('ABW', 'BX.GSR.ROYL.CD'): [80449], ('ABW', 'BX.GSR.TOTL.CD'): [80706], ('ABW', 'BX.GSR.TRAN.ZS'): [81674], ('ABW', 'BX.GSR.TRVL.ZS'): [81678], ('ABW', 'BX.KLT.DINV.CD.WD'): [80758], ('ABW', 'BX.KLT.DINV.WD.GD.ZS'): [80757], ('ABW', 'BX.PEF.TOTL.CD.WD'): [81364], ('ABW', 'BX.TRF.CURR.CD'): [81532], ('ABW', 'BX.TRF.PWKR.CD'): [81288], ('ABW', 'BX.TRF.PWKR.CD.DT'): [81287], ('ABW', 'BX.TRF.PWKR.DT.GD.ZS'): [81286], ('ABW', 'CM.MKT.INDX.ZG'): [81496], ('ABW', 'CM.MKT.LCAP.CD'): [81038], ('ABW', 'CM.MKT.LCAP.GD.ZS'): [81037], ('ABW', 'CM.MKT.LDOM.NO'): [81004], ('ABW', 'CM.MKT.TRAD.CD'): [81571], ('ABW', 'CM.MKT.TRAD.GD.ZS'): [81570], ('ABW', 'CM.MKT.TRNR'): [81572], ('ABW', 'DC.DAC.AUSL.CD'): [81116], ('ABW', 'DC.DAC.AUTL.CD'): [81117], ('ABW', 'DC.DAC.BELL.CD'): [81118], ('ABW', 'DC.DAC.CANL.CD'): [81119], ('ABW', 'DC.DAC.CECL.CD'): [81122], ('ABW', 'DC.DAC.CHEL.CD'): [81143], ('ABW', 'DC.DAC.CZEL.CD'): [81120], ('ABW', 'DC.DAC.DEUL.CD'): [81125], ('ABW', 'DC.DAC.DNKL.CD'): [81121], ('ABW', 'DC.DAC.ESPL.CD'): [81141], ('ABW', 'DC.DAC.FINL.CD'): [81123], ('ABW', 'DC.DAC.FRAL.CD'): [81124], ('ABW', 'DC.DAC.GBRL.CD'): [81145], ('ABW', 'DC.DAC.GRCL.CD'): [81126], ('ABW', 'DC.DAC.HUNL.CD'): [81127], ('ABW', 'DC.DAC.IRLL.CD'): [81129], ...}

# %%
# grps.agg(lambda x: 100 * sum(x.isnull()) / len(x)).plot.box()

# %%
nan_df = pd.DataFrame()
for col in df:
  nan_df[col] = [sum(df[col].isnull()) / len(df[col]) * 100]
nan_df = nan_df.drop(columns=["Country Name", "Country Code", "Indicator Name", "Indicator Code"])

# %%
nan_df.T.plot.line(xlabel="Year", ylabel="Missing Values %")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Missing Values %'>

# %%
df
# Out:
#        Country Name Country Code  \
# 0        Arab World          ARB
# 1        Arab World          ARB
# 2        Arab World          ARB
# 3        Arab World          ARB
# 4        Arab World          ARB
# ...             ...          ...
# 378571     Zimbabwe          ZWE
# 378572     Zimbabwe          ZWE
# 378573     Zimbabwe          ZWE
# 378574     Zimbabwe          ZWE
# 378575     Zimbabwe          ZWE
#
#                                            Indicator Name     Indicator Code  \
# 0       Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1                 Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 2       Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3       Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 4       Account ownership at a financial institution o...     FX.OWN.TOTL.ZS
# ...                                                   ...                ...
# 378571  Women who believe a husband is justified in be...     SG.VAW.REFU.ZS
# 378572  Women who were first married by age 15 (% of w...  SP.M15.2024.FE.ZS
# 378573  Women who were first married by age 18 (% of w...  SP.M18.2024.FE.ZS
# 378574  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
# 378575  Young people (ages 15-24) newly infected with HIV     SH.HIV.INCD.YG
#
#         1960  1961  1962  1963  1964  1965  ...          2011          2012  \
# 0        NaN   NaN   NaN   NaN   NaN   NaN  ...     82.783289     83.120303
# 1        NaN   NaN   NaN   NaN   NaN   NaN  ...     87.199474     87.512260
# 2        NaN   NaN   NaN   NaN   NaN   NaN  ...     75.958878     77.251714
# 3        NaN   NaN   NaN   NaN   NaN   NaN  ...     96.466418     96.435957
# 4        NaN   NaN   NaN   NaN   NaN   NaN  ...     22.260538           NaN
# ...      ...   ...   ...   ...   ...   ...  ...           ...           ...
# 378571   NaN   NaN   NaN   NaN   NaN   NaN  ...     16.900000           NaN
# 378572   NaN   NaN   NaN   NaN   NaN   NaN  ...      3.900000           NaN
# 378573   NaN   NaN   NaN   NaN   NaN   NaN  ...     30.500000           NaN
# 378574   NaN   NaN   NaN   NaN   NaN   NaN  ...     59.000000     59.200000
# 378575   NaN   NaN   NaN   NaN   NaN   NaN  ...  23000.000000  21000.000000
#
#                 2013          2014          2015          2016          2017  \
# 0          83.533457     83.897596     84.171599     84.510171           NaN
# 1          88.129881     87.275323     88.720097     89.308602     90.283638
# 2          78.165706     75.512153     78.211000     79.065508     81.102134
# 3          96.772853     96.466705     96.936319     97.290083     97.467915
# 4                NaN     30.277130           NaN           NaN     37.165211
# ...              ...           ...           ...           ...           ...
# 378571           NaN           NaN     14.500000           NaN           NaN
# 378572           NaN           NaN      3.700000           NaN           NaN
# 378573           NaN     33.500000     32.400000           NaN           NaN
# 378574     59.300000     59.400000     59.400000     59.500000     59.500000
# 378575  20000.000000  19000.000000  18000.000000  16000.000000  15000.000000
#
#                 2018     2019  2020
# 0                NaN      NaN   NaN
# 1          89.286856      NaN   NaN
# 2          79.248100      NaN   NaN
# 3          97.063959      NaN   NaN
# 4                NaN      NaN   NaN
# ...              ...      ...   ...
# 378571           NaN      NaN   NaN
# 378572           NaN      5.4   NaN
# 378573           NaN     33.7   NaN
# 378574     59.600000     59.6   NaN
# 378575  13000.000000  13000.0   NaN
#
# [378576 rows x 65 columns]

# %%
def get_indicator_data(df: pd.DataFrame, indicator_code: str):
    return df[df["Indicator Code"] == indicator_code]\
        .drop(columns=["Indicator Code", "Indicator Name", "Country Name"])\
        .set_index("Country Code")

# %%
def get_country_data(df: pd.DataFrame, country_code: str):
    return df[df["Country Code"] == country_code]\
        .drop(columns=["Country Code", "Country Name", "Indicator Name"])\
        .set_index("Indicator Code")

# %%
def get_year_data(df: pd.DataFrame, year: str):
    new_df = df[["Country Code", "Indicator Code", year]]
    ret_df = pd.DataFrame()
    for indicator_code, indicator_df in new_df.groupby("Indicator Code"):
        series = indicator_df.set_index("Country Code")[year]
        ret_df[indicator_code] = series
    return ret_df

# %%
def get_indicator_name(df, indicator_code):
  # Very, very inefficient. Fix by keeping a mapping of code to name
  return df[df["Indicator Code"] == indicator_code]["Indicator Name"].iloc[0]

# %%
def get_country_name(df, country_code):
  # Very, very inefficient. Fix by keeping a mapping of code to name
  return df[df["Country Code"] == country_code]["Country Name"].iloc[0]

# %%
get_year_data(df, "2018")
# Out:
#               AG.AGR.TRAC.NO  AG.CON.FERT.PT.ZS  AG.CON.FERT.ZS  \
# Country Code
# ARB                      NaN                NaN             NaN
# CSS                      NaN                NaN             NaN
# CEB                      NaN                NaN             NaN
# EAR                      NaN                NaN             NaN
# EAS                      NaN                NaN             NaN
# ...                      ...                ...             ...
# VIR                      NaN                NaN             NaN
# PSE                      NaN                NaN             NaN
# YEM                      NaN                NaN             NaN
# ZMB                      NaN                NaN             NaN
# ZWE                      NaN                NaN             NaN
#
#               AG.LND.AGRI.K2  AG.LND.AGRI.ZS  AG.LND.ARBL.HA  \
# Country Code
# ARB                      NaN             NaN             NaN
# CSS                      NaN             NaN             NaN
# CEB                      NaN             NaN             NaN
# EAR                      NaN             NaN             NaN
# EAS                      NaN             NaN             NaN
# ...                      ...             ...             ...
# VIR                      NaN             NaN             NaN
# PSE                      NaN             NaN             NaN
# YEM                      NaN             NaN             NaN
# ZMB                      NaN             NaN             NaN
# ZWE                      NaN             NaN             NaN
#
#               AG.LND.ARBL.HA.PC  AG.LND.ARBL.ZS  AG.LND.CREL.HA  \
# Country Code
# ARB                    0.140368             NaN             NaN
# CSS                    0.102596             NaN             NaN
# CEB                    0.355118             NaN             NaN
# EAR                    0.134060             NaN             NaN
# EAS                    0.100765             NaN             NaN
# ...                         ...             ...             ...
# VIR                    0.009348             NaN             NaN
# PSE                         NaN             NaN             NaN
# YEM                    0.038518             NaN             NaN
# ZMB                    0.218997             NaN             NaN
# ZWE                    0.277027             NaN             NaN
#
#               AG.LND.CROP.ZS  ...  per_sa_allsa.cov_q4_tot  \
# Country Code                  ...
# ARB                      NaN  ...                      NaN
# CSS                      NaN  ...                      NaN
# CEB                      NaN  ...                      NaN
# EAR                      NaN  ...                      NaN
# EAS                      NaN  ...                      NaN
# ...                      ...  ...                      ...
# VIR                      NaN  ...                      NaN
# PSE                      NaN  ...                      NaN
# YEM                      NaN  ...                      NaN
# ZMB                      NaN  ...                      NaN
# ZWE                      NaN  ...                      NaN
#
#               per_sa_allsa.cov_q5_tot  per_si_allsi.adq_pop_tot  \
# Country Code
# ARB                               NaN                       NaN
# CSS                               NaN                       NaN
# CEB                               NaN                       NaN
# EAR                               NaN                       NaN
# EAS                               NaN                       NaN
# ...                               ...                       ...
# VIR                               NaN                       NaN
# PSE                               NaN                       NaN
# YEM                               NaN                       NaN
# ZMB                               NaN                       NaN
# ZWE                               NaN                       NaN
#
#               per_si_allsi.ben_q1_tot  per_si_allsi.cov_pop_tot  \
# Country Code
# ARB                               NaN                       NaN
# CSS                               NaN                       NaN
# CEB                               NaN                       NaN
# EAR                               NaN                       NaN
# EAS                               NaN                       NaN
# ...                               ...                       ...
# VIR                               NaN                       NaN
# PSE                               NaN                       NaN
# YEM                               NaN                       NaN
# ZMB                               NaN                       NaN
# ZWE                               NaN                       NaN
#
#               per_si_allsi.cov_q1_tot  per_si_allsi.cov_q2_tot  \
# Country Code
# ARB                               NaN                      NaN
# CSS                               NaN                      NaN
# CEB                               NaN                      NaN
# EAR                               NaN                      NaN
# EAS                               NaN                      NaN
# ...                               ...                      ...
# VIR                               NaN                      NaN
# PSE                               NaN                      NaN
# YEM                               NaN                      NaN
# ZMB                               NaN                      NaN
# ZWE                               NaN                      NaN
#
#               per_si_allsi.cov_q3_tot  per_si_allsi.cov_q4_tot  \
# Country Code
# ARB                               NaN                      NaN
# CSS                               NaN                      NaN
# CEB                               NaN                      NaN
# EAR                               NaN                      NaN
# EAS                               NaN                      NaN
# ...                               ...                      ...
# VIR                               NaN                      NaN
# PSE                               NaN                      NaN
# YEM                               NaN                      NaN
# ZMB                               NaN                      NaN
# ZWE                               NaN                      NaN
#
#               per_si_allsi.cov_q5_tot
# Country Code
# ARB                               NaN
# CSS                               NaN
# CEB                               NaN
# EAR                               NaN
# EAS                               NaN
# ...                               ...
# VIR                               NaN
# PSE                               NaN
# YEM                               NaN
# ZMB                               NaN
# ZWE                               NaN
#
# [264 rows x 1434 columns]

# %%
def filter_df(df, ge_year=None, le_year=None, nan_thresh=None, particular_year = None):
  if nan_thresh is not None:
    na_kwargs = {"thresh": nan_thresh}
  else:
    na_kwargs = {}
  df = df.dropna(axis=0, how='all').dropna(axis=1, how='all').dropna(axis=1, **na_kwargs).iloc[:, :-1]
  if ge_year is not None:
    df = df.loc[:, df.columns >= ge_year]
  if le_year is not None:
    df = df.loc[:, df.columns <= le_year]
  if particular_year is not None:
    df = df.loc[:, df.columns == particular_year]
  return df

# %%
import matplotlib.pyplot as plt

def plot_indicator_box_across_years(df, indicator_code, **kwargs):
  ind_df = filter_df(get_indicator_data(df, indicator_code), **kwargs)

  fig, ax = plt.subplots()
  ax.set_xlabel("Year")
  ax.set_ylabel(get_indicator_name(df, indicator_code))
  sns.boxplot(data=ind_df, ax=ax)

# %%
plot_indicator_box_across_years(df, "SH.DYN.MORT", ge_year="2000")
plot_indicator_box_across_years(df, "SP.POP.0014.TO.ZS", nan_thresh=220)

# %%
def plot_indicator_some_countries(df, indicator_code, countries, **kwargs):
  tmp = df.loc[(df["Country Code"].isin(countries)) & (df["Indicator Code"] == indicator_code)].set_index("Country Name").iloc[:, 3:]
  tmp = filter_df(tmp, **kwargs)

  fig, ax = plt.subplots()
  ax.set_xlabel("Year")
  ax.set_ylabel(get_indicator_name(df, indicator_code))
  sns.lineplot(data=tmp.T, ax=ax)

# %%
plot_indicator_some_countries(df, "SP.POP.0014.TO.ZS", ["IND", "USA", "AUS"], ge_year="2008")
plot_indicator_some_countries(df, "SP.POP.0014.TO.ZS", ["IND", "USA", "AUS"])

# %%
def plot_country_some_indicators(df, country_code, indicators, **kwargs):
  tmp = df.loc[(df["Country Code"] == country_code) & (df["Indicator Code"].isin(indicators))].set_index("Indicator Name").iloc[:, 3:]
  tmp = filter_df(tmp, **kwargs)
  tmp = (tmp - tmp.min()) / tmp.max() # Scale
  
  fig, ax = plt.subplots()
  ax.set_xlabel("Year")
  ax.set_ylabel(get_country_name(df, country_code))
  sns.lineplot(data=tmp.T, ax=ax)

# %%
plot_country_some_indicators(df, "IND", ["SP.POP.0014.TO.ZS", "SP.URB.TOTL", "SH.DYN.MORT"], ge_year="2005")

# %%
df_RUS = get_country_data(df, "RUS")

# %%
df_RUS.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  9.100000e+01  9.500000e+01  9.700000e+01  9.500000e+01  9.600000e+01
# mean   6.890104e+06  7.028857e+06  6.945928e+06  7.186371e+06  7.191098e+06
# std    1.993424e+07  1.978860e+07  1.983107e+07  2.024248e+07  2.038918e+07
# min    0.000000e+00 -8.426913e-01 -1.387844e+06 -9.105655e-01 -9.423210e-01
# 25%    5.344912e+00  5.706050e+00  5.340602e+00  5.907317e+00  5.901865e+00
# 50%    1.208235e+01  1.232251e+01  1.192006e+01  1.191147e+01  1.315260e+01
# 75%    7.319564e+01  1.005975e+02  7.792169e+01  1.007736e+02  1.194848e+02
# max    1.198970e+08  1.212360e+08  1.225910e+08  1.239600e+08  1.253450e+08
#
#                1965          1966          1967          1968          1969  \
# count  9.700000e+01  9.600000e+01  9.700000e+01  9.500000e+01  9.900000e+01
# mean   7.196619e+06  7.317071e+06  7.280702e+06  7.485296e+06  7.227475e+06
# std    2.053919e+07  2.077493e+07  2.082671e+07  2.116774e+07  2.093472e+07
# min   -9.690112e-01 -1.545326e+00 -5.497220e+05 -1.612326e+00 -1.635056e+00
# 25%    4.934410e+00  5.892913e+00  5.802335e+00  6.181089e+00  5.144222e+00
# 50%    1.174104e+01  1.476065e+01  1.126419e+01  1.509800e+01  1.135664e+01
# 75%    7.884407e+01  1.595215e+02  7.945899e+01  9.936927e+01  7.614954e+01
# max    1.267450e+08  1.274680e+08  1.281960e+08  1.289280e+08  1.296640e+08
#
#        ...          2011          2012          2013          2014  \
# count  ...  9.110000e+02  9.590000e+02  9.370000e+02  1.014000e+03
# mean   ...  1.760427e+12  1.817167e+12  1.939313e+12  1.879226e+12
# std    ...  8.929270e+12  9.429771e+12  9.945075e+12  9.987680e+12
# min    ... -1.774673e+12 -2.086646e+12 -2.534373e+12 -2.608267e+12
# 25%    ...  7.262668e+00  6.213425e+00  6.244370e+00  5.499014e+00
# 50%    ...  4.317613e+01  3.815561e+01  3.987000e+01  3.859741e+01
# 75%    ...  1.945620e+06  4.682913e+05  4.216463e+05  2.212037e+04
# max    ...  9.498839e+13  9.926200e+13  9.934458e+13  9.857838e+13
#
#                2015          2016          2017          2018          2019  \
# count  9.810000e+02  9.760000e+02  9.230000e+02  8.570000e+02  6.980000e+02
# mean   1.952745e+12  1.973706e+12  2.207174e+12  2.621061e+12  3.328150e+12
# std    1.021242e+13  1.035849e+13  1.123202e+13  1.268613e+13  1.453656e+13
# min   -2.300325e+12 -2.380256e+12 -2.453507e+12 -2.531283e+12 -3.464826e+12
# 25%    6.200000e+00  5.517500e+00  5.381319e+00  5.047963e+00  6.175483e+00
# 50%    4.187000e+01  3.754500e+01  4.674280e+01  3.419260e+01  3.586042e+01
# 75%    5.863100e+04  5.427711e+04  1.245585e+05  6.947498e+05  7.123310e+07
# max    8.951589e+13  8.561610e+13  9.184320e+13  1.046296e+14  1.100461e+14
#
#                2020
# count  2.800000e+01
# mean   2.641498e+06
# std    1.360274e+07
# min    6.306273e-01
# 25%    7.239926e-01
# 50%    7.000000e+00
# 75%    6.500667e+01
# max    7.202503e+07
#
# [8 rows x 61 columns]

# %%
df_RUS.kurtosis()
# Out:
# 1960    13.673046
# 1961    14.074258
# 1962    14.453011
# 1963    14.120663
# 1964    14.327065
#           ...
# 2016    44.370967
# 2017    41.553938
# 2018    38.501144
# 2019    30.850038
# 2020    27.955444
# Length: 61, dtype: float64

# %%
df_RUS.skew()
# Out:
# 1960    3.533580
# 1961    3.558441
# 1962    3.604298
# 1963    3.566591
# 1964    3.594025
#           ...
# 2016    6.506924
# 2017    6.300617
# 2018    6.041276
# 2019    5.428596
# 2020    5.285514
# Length: 61, dtype: float64

# %%
df_RUS.var()
# Out:
# 1960    3.973739e+14
# 1961    3.915888e+14
# 1962    3.932715e+14
# 1963    4.097579e+14
# 1964    4.157185e+14
#             ...
# 2016    1.072984e+26
# 2017    1.261583e+26
# 2018    1.609380e+26
# 2019    2.113117e+26
# 2020    1.850345e+14
# Length: 61, dtype: float64

# %% [markdown]
# ### Best Fit Distribution, along with confidence interval

# %%
import matplotlib

colors = ['violet','cyan','green','brown','purple','red','yellowgreen','gray','blue','orange','indigo']

matplotlib.rcParams['figure.figsize'] = (16.0, 12.0)
matplotlib.style.use('ggplot')

def best_fit_distribution(data, bins=200, ax=None):
    
    # data is a numpy array. The list of distributions represent the potential candidates to be tried.
    
    """Model data by finding best fit distribution to data"""
    # Get histogram of original data
    y, x = np.histogram(data, bins=bins, density=True)
    x = (x + np.roll(x, -1))[:-1] / 2.0

    # Distributions to check
    DISTRIBUTIONS = [st.beta,st.cauchy,st.chi2,st.expon,st.logistic,st.gamma,st.lognorm,st.norm,st.uniform]
    
    number = len(DISTRIBUTIONS)
    
    # Best holders
    best_distribution = st.norm
    best_params = (0.0, 1.0)
    best_sse = np.inf
    
    if ax:
        ax.set_prop_cycle(color=colors)
    i = 0
    # Estimate distribution parameters from data
    for distribution in DISTRIBUTIONS:
        #print(best_distribution.name,best_params,best_sse)
        # Try to fit the distribution
        try:
            # Ignore warnings from data that can't be fit
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore')

                # fit dist to data
                params = distribution.fit(data)

                # Separate parts of parameters
                arg = params[:-2]
                loc = params[-2]
                scale = params[-1]

                # Calculate fitted PDF and error with fit in distribution
                pdf = distribution.pdf(x, loc=loc, scale=scale, *arg)
                sse = np.sum(np.power(y - pdf, 2.0))

                # if axis pass in add to plot
                try:
                    if ax:
                        pd.Series(pdf, x).plot(ax=ax, label = distribution.name, color = colors[i])
                        i += 1
                    end
                except Exception:
                    pass

                # identify if this distribution is better
                if best_sse > sse > 0:
                    best_distribution = distribution
                    best_params = params
                    best_sse = sse

        except Exception:
            pass

    return (best_distribution.name, best_params)

def make_pdf(dist, params, size=10000):
    """Generate distributions's Probability Distribution Function """
    
    # Given the best parameters

    # Separate parts of parameters
    arg = params[:-2]
    loc = params[-2]
    scale = params[-1]

    # Get sane start and end points of distribution
    start = dist.ppf(0.01, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.01, loc=loc, scale=scale)
    end = dist.ppf(0.99, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.99, loc=loc, scale=scale)

    # Build PDF and turn into pandas Series
    x = np.linspace(start, end, size)
    y = dist.pdf(x, loc=loc, scale=scale, *arg)
    pdf = pd.Series(y, x)

    return pdf

# %%
def fit_distribution_indicator_year(df, indicator_code, year, **kwargs):
    
    # The DF passed should only contain countries
    # indicator_code is a list of indicator codes.
    show = True
    
    for indicator in indicator_code:
        
        plt.figure(figsize=(12,8))
        temp = df[["Country Name", "Country Code", "Indicator Name", "Indicator Code", year]]
        name = temp[temp["Indicator Code"] == indicator]["Indicator Name"].iloc[0]
        temp = temp[temp["Indicator Code"] == indicator]
        data = temp[temp.columns[-1]].values
        
        data = data[~np.isnan(data)]
        if show:
            ax = temp[year].plot(kind='hist', bins=80, density=True, alpha=0.3, edgecolor = 'white')
        # Save plot limits
            dataYLim = ax.get_ylim()

         # Find best fit distribution, also fits all the distribution in the plot. If don't 
         # really want to do this, use ax = None in the parameters.
        if show:
            best_fit_name, best_fit_params = best_fit_distribution(data, 80, ax)
        else:
            best_fit_name, best_fit_params = best_fit_distribution(data, 80, None)
        best_dist = getattr(st, best_fit_name)
    
        if show:
            ax.set_xlabel(name + " "+year)    
            ax.set_ylim(dataYLim)
            ax.set_title('Different Estimates')
            #ax.set_xlabel('Value')
            ax.set_ylabel('PDF(x)')
            ax.legend(loc = 'best')
            # plt.savefig('graphs/all.png',dpi = 200)
    
    #     # Make PDF with best params 
        pdf = make_pdf(best_dist, best_fit_params)

#     # Display
        plt.figure(figsize=(12,8))
        ax = pdf.plot(lw=2, label='PDF', legend=True)
        temp[year].plot(kind='hist', bins=80, density=True, alpha=0.5, label=name+" "+year, legend=True, ax=ax, edgecolor = 'white')

        param_names = (best_dist.shapes + ', loc, scale').split(', ') if best_dist.shapes else ['loc', 'scale']
        param_str = ', '.join(['{}={:0.2f}'.format(k,v) for k,v in zip(param_names, best_fit_params)])
        dist_str = '{}({})'.format(best_fit_name, param_str)

        ax.set_title(u'Best Fit Distribution \n' + dist_str)
        ax.set_xlabel("Indicator")
        ax.set_ylabel('PDF(X)')
        # plt.savefig('graphs/best.png',dpi = 200)

# %%
fit_distribution_indicator_year(country_df, ["NY.GDP.MKTP.KD.ZG"], "2012")

# %% [markdown]
# ### Parameter Estimation
#
# For logistic distribution, 2 parameters to be estimated mean and scale. Mean estimated by sample mean and scale estimated by sqrt(3 * sample variance)/pi

# %%
indicator1 = "NY.GDP.MKTP.KD.ZG"

temp1 = country_df[["Country Name", "Country Code", "Indicator Name", "Indicator Code", "2012"]]
temp1 = temp1[temp1["Indicator Code"] == indicator1]
data1 = temp1[temp1.columns[-1]].values
data1 = data1[~np.isnan(data1)]

mean1 = data1.mean()
scale1 = np.sqrt(3*data1.var(ddof = 1))/np.pi

print(mean1, scale1)
# Out:
# 3.4415841332088197 5.526510289196146

# %%
fit_distribution_indicator_year(country_df, ["SP.POP.0014.TO.ZS"], "2008")

# %% [markdown]
# ### Parameter Estimation
#
# Since the predicted distribution is uniform, the estimate is just the range over which the distribution is uniform i.e. max - min of the data

# %%
indicator2 = "SP.POP.0014.TO.ZS"

temp2 = country_df[["Country Name", "Country Code", "Indicator Name", "Indicator Code", "2008"]]
temp2 = temp2[temp2["Indicator Code"] == indicator2]
data2 = temp2[temp2.columns[-1]].values
data2 = data2[~np.isnan(data2)]


loc2 = np.min(data2)
scale2 = np.max(data2) - np.min(data2)

print(loc,scale)
# Out:
# 12.7372631509811 37.1307119230276

# %%
fit_distribution_indicator_year(country_df, ["SP.URB.TOTL"], "2008")

# %% [markdown]
# ### Parameter Estimation
#
# For cauchy distribution, moments do not exist. So estimate is made for parameters loc and scale as follows: Take the median of the middle 24% of the sample for loc, and estimate the shape using median of absolute values. However, noting that even the sample mean is an estimate of the loc parameter (but with increasing variance with increase in sample size) with a finite set of samples it may be considered an alternative candidate for estimating loc, this is also calculated.

# %%
indicator3 = "SP.URB.TOTL"

temp3 = country_df[["Country Name", "Country Code", "Indicator Name", "Indicator Code", "2008"]]
temp3 = temp3[temp3["Indicator Code"] == indicator3]
data3 = temp3[temp3.columns[-1]].values
data3 = data3[~np.isnan(data3)]
abs_data3 = np.abs(data3)

loc3 = st.trim_mean(data3,0.38,axis = 0)
loc3_alt = data3.mean()
scale3 = np.median(abs_data3)

print(loc3, loc3_alt ,scale3)
# Out:
# 3000954.7358490564 15834953.0 2744952.0

# %%
confidence = [0.99, 0.95, 0.9]
def confidence_interval(data):
    # calculates the confidence of the population mean using T-Distribution
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), st.sem(a)
    for c in confidence:
        print(c)
        h = se * st.t.ppf((1 + c) / 2., n-1)
        print(m-h,m,m+h)

# %%
fit_distribution_indicator_year(country_df, ["SH.DYN.MORT"], "2014")

# %%
def ratio_of_variance(df, year1, year2, indicator, confidence, **kwargs):
    
    temp = df[["Country Name", "Country Code", "Indicator Name", "Indicator Code", year1]]
    name = temp[temp["Indicator Code"] == indicator]["Indicator Name"].iloc[0]
    temp = temp[temp["Indicator Code"] == indicator]
    data1 = temp[temp.columns[-1]].values
    data1 = data1[~np.isnan(data1)]
    
    temp = df[["Country Name", "Country Code", "Indicator Name", "Indicator Code", year2]]
    name = temp[temp["Indicator Code"] == indicator]["Indicator Name"].iloc[0]
    temp = temp[temp["Indicator Code"] == indicator]
    data2 = temp[temp.columns[-1]].values
    data2 = data2[~np.isnan(data2)]
    
    n1 = data1.shape[0]
    n2 = data2.shape[0]
    
    s1 = np.var(data1, ddof = 1)
    s2 = np.var(data2, ddof = 1)
    print("s1 : " + str(s1) + " s2 : " + str(s2))
    print("ratio of variance : " + str(s1/s2))
    
    intervals = []
    
    for c in confidence:
        lower = st.f.ppf((1-c)/2, n1-1, n2-1)
        higher = st.f.ppf((1+c)/2, n1-1, n2-1)
        intervals.append((s1/(lower*s2),s1/(higher*s2)))
        print("Confidence : " + str(c) + " Interval : [" + str((s1/(lower*s2))) + " " + str((s1/(higher*s2))) + "]")   
    return intervals

# %%
ratio_of_variance(df, "2011", "2015", "EG.CFT.ACCS.ZS", [0.8,0.9,0.95,0.99])

# %%
def difference_between_population_mean(df, year1, year2, indicator, confidence, **kwargs):
    
    temp = df[["Country Name", "Country Code", "Indicator Name", "Indicator Code", year1]]
    name = temp[temp["Indicator Code"] == indicator]["Indicator Name"].iloc[0]
    temp = temp[temp["Indicator Code"] == indicator]
    data1 = temp[temp.columns[-1]].values
    data1 = data1[~np.isnan(data1)]
    
    temp = df[["Country Name", "Country Code", "Indicator Name", "Indicator Code", year2]]
    name = temp[temp["Indicator Code"] == indicator]["Indicator Name"].iloc[0]
    temp = temp[temp["Indicator Code"] == indicator]
    data2 = temp[temp.columns[-1]].values
    data2 = data2[~np.isnan(data2)]
    n1 = data1.shape[0]
    n2 = data2.shape[0]
    print(n1,n2)

    mu1 = np.mean(data1)
    mu2 = np.mean(data2)
    print(mu1, mu2)
    s1 = np.var(data1, ddof = 1)
    s2 = np.var(data2, ddof = 1)
    s = (n1-1)*s1 + (n2-1)*s2
    s = math.sqrt(s/(n1 + n2 -2))
    n_root = math.sqrt((1/n1) + (1/n2))
    print(s)
    print("difference between mean : " + str(mu1 - mu2))
    
    intervals = []
    
    for c in confidence:
        diff = (st.t.ppf((1-c)/2,n1 + n2 -2))*s*n_root
        lower = mu1 - mu2 - diff
        higher = mu1 - mu2 + diff
        intervals.append((s1/(lower*s2),s1/(higher*s2)))
        print("Confidence : " + str(c) + " Interval : [" + str(lower) + " " + str(higher) + "]")   
    return intervals

# %%
difference_between_population_mean(df, "2011", "2015", "EG.CFT.ACCS.ZS", [0.8,0.9,0.95,0.99])

# %%
def ratio_of_variance_random_sampling(df, year1, year2, indicator, confidence, sample_size = 30):
    
    temp = df[["Country Name", "Country Code", "Indicator Name", "Indicator Code", year1]]
    name = temp[temp["Indicator Code"] == indicator]["Indicator Name"].iloc[0]
    temp = temp[temp["Indicator Code"] == indicator]
    data1 = temp[temp.columns[-1]].values
    data1 = data1[~np.isnan(data1)]
    
    temp = df[["Country Name", "Country Code", "Indicator Name", "Indicator Code", year2]]
    name = temp[temp["Indicator Code"] == indicator]["Indicator Name"].iloc[0]
    temp = temp[temp["Indicator Code"] == indicator]
    data2 = temp[temp.columns[-1]].values
    data2 = data2[~np.isnan(data2)]
    n1 = data1.shape[0]
    n2 = data2.shape[0]
    if sample_size > min(n1,n2):
        print("sample size greater than total population, reducing it to min of 2 population")
        sample_size = min(n1,n2)
        
    s1 = np.var(data1, ddof = 1)
    s2 = np.var(data2, ddof = 1)
    print("s1 : " + str(s1) + " s2 : " + str(s2))
    print("ratio of variance : " + str(s1/s2))
    for c in confidence:
        sample1 = data1[np.random.choice(n1, sample_size, replace=False)]
        sample2 = data2[np.random.choice(n2, sample_size, replace=False)]
        s1_s = np.var(sample1, ddof = 1)
        s2_s = np.var(sample2, ddof = 1)
        
        lower = st.f.ppf((1-c)/2, sample_size-1, sample_size-1)
        higher = st.f.ppf((1+c)/2, sample_size-1, sample_size-1)
        intervals.append((s1_s/(lower*s2_s),s1_s/(higher*s2_s)))
        print("Confidence : " + str(c) + " Interval : [" + str(s1_s/(lower*s2_s)) + " " + str(s1_s/(higher*s2_s)) + "]")   
    return intervals

# %%
ratio_of_variance_random_sampling(df, "2011", "2015", "EG.CFT.ACCS.ZS", [0.8,0.9,0.95,0.99], 60)

# %%
def difference_between_population_mean_random_sampling(df, year1, year2, indicator, confidence, sample_size = 30):
    
    temp = df[["Country Name", "Country Code", "Indicator Name", "Indicator Code", year1]]
    name = temp[temp["Indicator Code"] == indicator]["Indicator Name"].iloc[0]
    temp = temp[temp["Indicator Code"] == indicator]
    data1 = temp[temp.columns[-1]].values
    data1 = data1[~np.isnan(data1)]
    print(type(data1))
    
    temp = df[["Country Name", "Country Code", "Indicator Name", "Indicator Code", year2]]
    name = temp[temp["Indicator Code"] == indicator]["Indicator Name"].iloc[0]
    temp = temp[temp["Indicator Code"] == indicator]
    data2 = temp[temp.columns[-1]].values
    data2 = data2[~np.isnan(data2)]
    n1 = data1.shape[0]
    n2 = data2.shape[0]
    if sample_size > min(n1,n2):
        print("sample size greater than total population, reducing it to min of 2 population")
        sample_size = min(n1,n2)
    mu1 = np.mean(data1)
    mu2 = np.mean(data2)
    print(mu1, mu2)
    print("difference between mean : " + str(mu1 - mu2))
    
    for c in confidence:
        sample1 = data1[np.random.choice(n1, sample_size, replace=False)]
        sample2 = data2[np.random.choice(n2, sample_size, replace=False)]
        
        mu1_s = np.mean(sample1)
        mu2_s = np.mean(sample2)
        s1_s = np.var(sample1, ddof = 1)
        s2_s = np.var(sample2, ddof = 1)
        s = (sample_size-1)*s1 + (sample_size-1)*s2
        s = math.sqrt(s/(2*sample_size -2))
        n_root = math.sqrt(2/sample_size)
        
        diff = (st.t.ppf((1-c)/2,2*sample_size -2))*s*n_root
        lower = mu1_s - mu2_s - diff
        higher = mu1_s - mu2_s + diff
        intervals.append((lower,higher))
        print("Confidence : " + str(c) + " Interval : [" + str(lower) + " " + str(higher) + "]")  
    return intervals

# %%
difference_between_population_mean_random_sampling(df, "2011", "2015", "EG.CFT.ACCS.ZS", [0.8,0.9,0.95,0.99],60)
